# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('EUP data set- PM interview. .xlsx')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                   State          GDP  Total State Budget\n  \
# 0            BIHAR (10) 7.570260e+05          2.183030e+05
# 1      WEST BENGAL (19) 1.510762e+06          2.556770e+05
# 2        JHARKHAND (20) 3.613810e+05          9.127700e+04
# 3           ODISHA (21) 5.860000e+05          1.700000e+05
# 4        RAJASTHAN (08) 1.198348e+06          1.102008e+05
# 5          GUJARAT (24) 1.879826e+06          2.270290e+05
# 6      MAHARASHTRA (27) 2.981024e+06          4.379610e+05
# 7   ANDHRA PRADESH (28) 1.061781e+06          2.297790e+05
# 8        KARNATAKA (29) 1.702227e+06          2.462070e+05
# 9           KERALA (32) 8.762830e+05          2.144790e+05
# 10       TAMILNADU (33) 2.136351e+06          3.290350e+05
# 11       TELANGANA (36) 1.154608e+06          1.693830e+05
# 12   UTTAR PRADESH (09) 2.173990e+06          5.502710e+05
# 13    CHHATTISGARH (22) 3.830980e+05          9.710600e+04
# 14  MADHYA PRADESH (23) 1.132116e+06          1.646770e+05
#
# ...

# %%
df.shape
# Out:
# (15, 49)

# %%
df.columns
# Out:
# Index(['State', 'GDP', 'Total State Budget\n',
#        'Welfare of SC, ST, OBC, and Minorities\nBudget',
#        'Nutrition and Social welfare\nBudgets', 'Rural Development Budgets',
#        'Agriculture & allied activities\n',
#        'No. of Persons in BPL\n(Based on MRP Consumption)',
#        'MDI % = people in multidimensional poverty\n(Urban + Rural)\n\nNITI AAYOG',
#        'No of SHG ', '# Village Organisation {VO}',
#        '# SHG \nreceived Revolving Fund \n\noverall',
#        'Amount of RF disbursed \n(in lakhs)', 'avg RF received',
#        'No of SHG received bank Linkage  between \nApril 2020 to March 2021',
#        'no of SHG availed bank loan FY 21-22',
#        'Amount disbursed through Bank Linkage in between April 2020 to March 2021',
#        'Total Households', 'Total Households considered for deprivation',
#        'No. of Deprived Households with deprivation criteria Only one room with kucha walls and kucha roof',
# ...

# %%
df['State']
# Out:
# 0              BIHAR (10)
# 1        WEST BENGAL (19)
# 2          JHARKHAND (20)
# 3             ODISHA (21)
# 4          RAJASTHAN (08)
# 5            GUJARAT (24)
# 6        MAHARASHTRA (27)
# 7     ANDHRA PRADESH (28)
# 8          KARNATAKA (29)
# 9             KERALA (32)
# 10         TAMILNADU (33)
# 11         TELANGANA (36)
# 12     UTTAR PRADESH (09)
# 13      CHHATTISGARH (22)
# 14    MADHYA PRADESH (23)
# Name: State, dtype: object

# %%
df['No of SHG ']
# Out:
# 0    9.902150e+05
# 1    9.106930e+05
# 2    2.642920e+05
# 3    4.876890e+05
# 4    1.964410e+05
# 5    2.606460e+05
# 6    5.325170e+05
# 7    8.199360e+05
# 8    2.073880e+05
# 9    2.453900e+05
# 10   2.901700e+05
# 11   4.077370e+05
# 12   5.512270e+05
# 13   2.044100e+05
# 14   3.428760e+05
# Name: No of SHG , dtype: float64

# %%
df['Total Households']
# Out:
# 0    1.782907e+07
# 1    1.575675e+07
# 2    5.044234e+06
# 3    8.677615e+06
# 4    1.022307e+07
# 5    6.920473e+06
# 6    1.384196e+07
# 7    9.344180e+06
# 8    8.048664e+06
# 9    6.319215e+06
# 10   1.008812e+07
# 11   5.643739e+06
# 12   2.601559e+07
# 13   4.540999e+06
# 14   1.128895e+07
# Name: Total Households, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(8,5))
df.plot(x="State", y=["Total Households", "Total Households considered for deprivation"], kind="bar")
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.plot(x="State", y=["No. of Deprived Households with Exactly 1", "No. of Deprived Households with Exactly 2","No. of Deprived Households with Exactly 3","No. of Deprived Households with Exactly 4","No. of Deprived Households with Exactly 5","No. of Deprived Households with Exactly 6","No. of Deprived Households with Exactly 7"], kind="bar", figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
pd.pandas.set_option('display.max_columns', None)
df.describe()
# Out:
#                GDP  Total State Budget\n  \
# count 1.500000e+01          1.500000e+01
# mean  1.326321e+06          2.340923e+05
# std   7.388925e+05          1.252098e+05
# min   3.613810e+05          9.127700e+04
# 25%   8.166545e+05          1.670300e+05
# 50%   1.154608e+06          2.183030e+05
# 75%   1.791026e+06          2.509420e+05
# max   2.981024e+06          5.502710e+05
#
#        Welfare of SC, ST, OBC, and Minorities\nBudget  \
# count                                    1.500000e+01
# mean                                     6.727674e+03
# std                                      6.143761e+03
# min                                      1.340000e+03
# 25%                                      2.029272e+03
# 50%                                      3.998000e+03
# 75%                                      9.497483e+03
# max                                      1.999272e+04
#
#        Nutrition and Social welfare\nBudgets  Rural Development Budgets  \
# ...

# %%
df1=df.iloc[:,33:40]

# %%
pd.set_option('float_format', '{:f}'.format)
df1
# Out:
#     No. of Deprived Households with Exactly 1  \
# 0                              3857092.000000
# 1                              3706716.000000
# 2                              1177511.000000
# 3                              1969249.000000
# 4                              1694293.000000
# 5                              1282837.000000
# 6                              2548839.000000
# 7                              1943430.000000
# 8                              1387384.000000
# 9                               902277.000000
# 10                             1673459.000000
# 11                              777493.000000
# 12                             4444985.000000
# 13                             1006602.000000
# 14                             1819582.000000
#
#     No. of Deprived Households with Exactly 2  \
# 0                              3829602.000000
# 1                              3560262.000000
# 2                               941881.000000
# ...

# %%
pd.set_option('float_format', '{:f}'.format)
df1.describe()
# Out:
#        No. of Deprived Households with Exactly 1  \
# count                                  15.000000
# mean                              2012783.266667
# std                               1137906.761877
# min                                777493.000000
# 25%                               1230174.000000
# 50%                               1694293.000000
# 75%                               2259044.000000
# max                               4444985.000000
#
#        No. of Deprived Households with Exactly 2  \
# count                                  15.000000
# mean                              1831984.533333
# std                               1078712.369778
# min                                426335.000000
# 25%                               1002307.500000
# 50%                               1710000.000000
# 75%                               2116187.500000
# max                               3829602.000000
#
#        No. of Deprived Households with Exactly 3  \
# ...

# %%
df[['State','No. of Deprived Households with Exactly 3']]
# Out:
#                   State  No. of Deprived Households with Exactly 3
# 0            BIHAR (10)                             2359491.000000
# 1      WEST BENGAL (19)                             2010528.000000
# 2        JHARKHAND (20)                              422750.000000
# 3           ODISHA (21)                             1201966.000000
# 4        RAJASTHAN (08)                             1217962.000000
# 5          GUJARAT (24)                              464360.000000
# 6      MAHARASHTRA (27)                             1042240.000000
# 7   ANDHRA PRADESH (28)                              829930.000000
# 8        KARNATAKA (29)                              389661.000000
# 9           KERALA (32)                              104505.000000
# 10       TAMILNADU (33)                              900587.000000
# 11       TELANGANA (36)                              416547.000000
# 12   UTTAR PRADESH (09)                             1735381.000000
# ...

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y="No. of Deprived Households with Exactly 3", data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')
