# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('EUP data set- PM interview. .xlsx')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                   State        GDP  Total State Budget\n  \
# 0            BIHAR (10)   757026.0             218303.00
# 1      WEST BENGAL (19)  1510762.0             255677.00
# 2        JHARKHAND (20)   361381.0              91277.00
# 3           ODISHA (21)   586000.0             170000.00
# 4        RAJASTHAN (08)  1198348.0             110200.82
# 5          GUJARAT (24)  1879826.0             227029.00
# 6      MAHARASHTRA (27)  2981024.0             437961.00
# 7   ANDHRA PRADESH (28)  1061781.0             229779.00
# 8        KARNATAKA (29)  1702227.0             246207.00
# 9           KERALA (32)   876283.0             214479.00
# 10       TAMILNADU (33)  2136351.0             329035.00
# 11       TELANGANA (36)  1154608.0             169383.00
# 12   UTTAR PRADESH (09)  2173990.0             550271.00
# 13    CHHATTISGARH (22)   383098.0              97106.00
# 14  MADHYA PRADESH (23)  1132116.0             164677.00
#
# ...

# %%
df.shape
# Out:
# (15, 49)

# %%
df.columns
# Out:
# Index(['State', 'GDP', 'Total State Budget\n',
#        'Welfare of SC, ST, OBC, and Minorities\nBudget',
#        'Nutrition and Social welfare\nBudgets', 'Rural Development Budgets',
#        'Agriculture & allied activities\n',
#        'No. of Persons in BPL\n(Based on MRP Consumption)',
#        'MDI % = people in multidimensional poverty\n(Urban + Rural)\n\nNITI AAYOG',
#        'No of SHG ', '# Village Organisation {VO}',
#        '# SHG \nreceived Revolving Fund \n\noverall',
#        'Amount of RF disbursed \n(in lakhs)', 'avg RF received',
#        'No of SHG received bank Linkage  between \nApril 2020 to March 2021',
#        'no of SHG availed bank loan FY 21-22',
#        'Amount disbursed through Bank Linkage in between April 2020 to March 2021',
#        'Total Households', 'Total Households considered for deprivation',
#        'No. of Deprived Households with deprivation criteria Only one room with kucha walls and kucha roof',
# ...

# %%
df['State']
# Out:
# 0              BIHAR (10)
# 1        WEST BENGAL (19)
# 2          JHARKHAND (20)
# 3             ODISHA (21)
# 4          RAJASTHAN (08)
# 5            GUJARAT (24)
# 6        MAHARASHTRA (27)
# 7     ANDHRA PRADESH (28)
# 8          KARNATAKA (29)
# 9             KERALA (32)
# 10         TAMILNADU (33)
# 11         TELANGANA (36)
# 12     UTTAR PRADESH (09)
# 13      CHHATTISGARH (22)
# 14    MADHYA PRADESH (23)
# Name: State, dtype: object

# %%
df['No of SHG ']
# Out:
# 0     990215.0
# 1     910693.0
# 2     264292.0
# 3     487689.0
# 4     196441.0
# 5     260646.0
# 6     532517.0
# 7     819936.0
# 8     207388.0
# 9     245390.0
# 10    290170.0
# 11    407737.0
# 12    551227.0
# 13    204410.0
# 14    342876.0
# Name: No of SHG , dtype: float64

# %%
df['Total Households']
# Out:
# 0     17829066.0
# 1     15756750.0
# 2      5044234.0
# 3      8677615.0
# 4     10223073.0
# 5      6920473.0
# 6     13841960.0
# 7      9344180.0
# 8      8048664.0
# 9      6319215.0
# 10    10088119.0
# 11     5643739.0
# 12    26015592.0
# 13     4540999.0
# 14    11288946.0
# Name: Total Households, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(8,5))
df.plot(x="State", y=["Total Households", "Total Households considered for deprivation"], kind="bar")
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.plot(x="State", y=["No. of Deprived Households with Exactly 1", "No. of Deprived Households with Exactly 2","No. of Deprived Households with Exactly 3","No. of Deprived Households with Exactly 4","No. of Deprived Households with Exactly 5","No. of Deprived Households with Exactly 6","No. of Deprived Households with Exactly 7"], kind="bar", figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
pd.pandas.set_option('display.max_columns', None)
df.describe()
# Out:
#                 GDP  Total State Budget\n  \
# count  1.500000e+01             15.000000
# mean   1.326321e+06         234092.321333
# std    7.388925e+05         125209.776090
# min    3.613810e+05          91277.000000
# 25%    8.166545e+05         167030.000000
# 50%    1.154608e+06         218303.000000
# 75%    1.791026e+06         250942.000000
# max    2.981024e+06         550271.000000
#
#        Welfare of SC, ST, OBC, and Minorities\nBudget  \
# count                                       15.000000
# mean                                      6727.673933
# std                                       6143.761291
# min                                       1340.000000
# 25%                                       2029.272000
# 50%                                       3998.000000
# 75%                                       9497.482500
# max                                      19992.720000
#
#        Nutrition and Social welfare\nBudgets  Rural Development Budgets  \
# ...

# %%
df1=df.iloc[:,33:40]

# %%
pd.set_option('float_format', '{:f}'.format)
df1
# Out:
#     No. of Deprived Households with Exactly 1  \
# 0                              3857092.000000
# 1                              3706716.000000
# 2                              1177511.000000
# 3                              1969249.000000
# 4                              1694293.000000
# 5                              1282837.000000
# 6                              2548839.000000
# 7                              1943430.000000
# 8                              1387384.000000
# 9                               902277.000000
# 10                             1673459.000000
# 11                              777493.000000
# 12                             4444985.000000
# 13                             1006602.000000
# 14                             1819582.000000
#
#     No. of Deprived Households with Exactly 2  \
# 0                              3829602.000000
# 1                              3560262.000000
# 2                               941881.000000
# ...

# %%
pd.set_option('float_format', '{:f}'.format)
df1.describe()
# Out:
#        No. of Deprived Households with Exactly 1  \
# count                                  15.000000
# mean                              2012783.266667
# std                               1137906.761877
# min                                777493.000000
# 25%                               1230174.000000
# 50%                               1694293.000000
# 75%                               2259044.000000
# max                               4444985.000000
#
#        No. of Deprived Households with Exactly 2  \
# count                                  15.000000
# mean                              1831984.533333
# std                               1078712.369778
# min                                426335.000000
# 25%                               1002307.500000
# 50%                               1710000.000000
# 75%                               2116187.500000
# max                               3829602.000000
#
#        No. of Deprived Households with Exactly 3  \
# ...

# %%
df[['State','No. of Deprived Households with Exactly 3']]
# Out:
#                   State  No. of Deprived Households with Exactly 3
# 0            BIHAR (10)                             2359491.000000
# 1      WEST BENGAL (19)                             2010528.000000
# 2        JHARKHAND (20)                              422750.000000
# 3           ODISHA (21)                             1201966.000000
# 4        RAJASTHAN (08)                             1217962.000000
# 5          GUJARAT (24)                              464360.000000
# 6      MAHARASHTRA (27)                             1042240.000000
# 7   ANDHRA PRADESH (28)                              829930.000000
# 8        KARNATAKA (29)                              389661.000000
# 9           KERALA (32)                              104505.000000
# 10       TAMILNADU (33)                              900587.000000
# 11       TELANGANA (36)                              416547.000000
# 12   UTTAR PRADESH (09)                             1735381.000000
# ...

# %%
df.plot(x="State", y=["No. of Deprived Households with Exactly 3","No. of Deprived Households with Exactly 4","No. of Deprived Households with Exactly 5","No. of Deprived Households with Exactly 6","No. of Deprived Households with Exactly 7"], kind="bar", figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.plot(x="State", y=['No. of Deprived Households with deprivation criteria Only one room with kucha walls and kucha roof','No. of Deprived Households with deprivation criteria Female headed households with no adult male member between age 16 to 59','No. of Deprived Households with deprivation criteria Landless households deriving major part of their income from manual casual labour'], kind="bar", figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria Only one room with kucha walls and kucha roof', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria No adult member between age 16 to 59', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria Female headed households with no adult male member between age 16 to 59', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria Disabled member and no able bodied adult member', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria SC/ST households', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria No literate adult above 25 years', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No. of Deprived Households with deprivation criteria Landless households deriving major part of their income from manual casual labour', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='No of SHG ', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='Rural Development Budgets', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='Agriculture & allied activities\n', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')

# %%
plt.figure(figsize=(15, 4))
plots = sns.barplot(x="State", y='avg RF received', data=df)
plt.xticks(rotation=45)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 4),
                   textcoords='offset points')
